# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('PERSONAS (DEPARTAMENTAL) 2025.csv')
df.head()
# Out:
#    DIRECTORIO  SECUENCIA_ENCUESTA  SECUENCIA_P  ORDEN  P6020  P6040  P6051  \
# 0     8369550                   1            1      1      2     45      1
# 1     8369550                   2            1      2      1     25      7
# 2     8369550                   3            1      3      2     16      9
# 3     8369550                   4            1      4      1     10      9
# 4     8369551                   1            1      1      2     62      1
#
#         FEX_C  P6090  P5665  P8563  P51  P55  P774  P6160  P8587  P8587S1  \
# 0  472.131901      1      2    NaN  NaN  NaN   NaN    1.0    5.0     11.0
# 1  472.131901      1      2    NaN  NaN  NaN   NaN    1.0    8.0      1.0
# 2  472.131901      1      2    NaN  NaN  NaN   NaN    1.0    NaN      NaN
# 3  472.131901      1      2    NaN  NaN  NaN   NaN    1.0    NaN      NaN
# 4  308.854319      1      2    NaN  NaN  NaN   NaN    1.0    4.0      7.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 235350 entries, 0 to 235349
# Data columns (total 29 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   DIRECTORIO          235350 non-null  int64
#  1   SECUENCIA_ENCUESTA  235350 non-null  int64
#  2   SECUENCIA_P         235350 non-null  int64
#  3   ORDEN               235350 non-null  int64
#  4   P6020               235350 non-null  int64
#  5   P6040               235350 non-null  int64
#  6   P6051               235350 non-null  int64
#  7   FEX_C               235350 non-null  float64
#  8   P6090               235350 non-null  int64
#  9   P5665               235350 non-null  int64
#  10  P8563               7303 non-null    float64
#  11  P51                 14307 non-null   float64
#  12  P55                 14307 non-null   float64
#  13  P774                14227 non-null   float64
#  14  P6160               221043 non-null  float64
# ...

# %%
df.shape
# Out:
# (235350, 29)

# %%
'''df = df.rename(columns={
    'P6020': 'sexo',
    'P6040': 'edad',
    'P6051': 'parentesco',
    'P6090': 'afiliacion_salud',
    'P5665': 'problema_salud_30d',
    'P8563': 'accion_salud',
    'P51':   'lugar_permanencia',
    'P55':   'recibe_alimentacion',
    'P774':  'quien_paga_alimentacion',
    'P6160': 'sabe_leer_escribir',
    'P8586': 'estudia_actualmente',
    'P8587': 'nivel_educativo_max',
    'P8587s1': 'grado_aprobado',
    'P1088': 'nivel_matriculado',
    'P1088s1': 'grado_cursa',
    'P6180': 'alimentacion_plantel',
    'P3336s1': 'mod_presencial',
    'P3336s2': 'modalidad_trabajo',
    'P3336s3': 'mod_alternancia',
    'P3337': 'contacto_maestros',
    'P6240': 'actividad_principal',
    'P6250': 'trabajo_pago_1h',
    'P6260': 'tenia_trabajo_no_trabajo',
    'P6270': 'trabajo_sin_remuneracion',
    'P6351': 'disponible_trabajar',
    'P7250': 'semanas_buscando',
    'P6920': 'cotiza_pension',
    'P1082s2': 'tiene_smartphone'
})
df.head()'''
# Out:
# "df = df.rename(columns={\n    'P6020': 'sexo',\n    'P6040': 'edad',\n    'P6051': 'parentesco',\n    'P6090': 'afiliacion_salud',\n    'P5665': 'problema_salud_30d',\n    'P8563': 'accion_salud',\n    'P51':   'lugar_permanencia',\n    'P55':   'recibe_alimentacion',\n    'P774':  'quien_paga_alimentacion',\n    'P6160': 'sabe_leer_escribir',\n    'P8586': 'estudia_actualmente',\n    'P8587': 'nivel_educativo_max',\n    'P8587s1': 'grado_aprobado',\n    'P1088': 'nivel_matriculado',\n    'P1088s1': 'grado_cursa',\n    'P6180': 'alimentacion_plantel',\n    'P3336s1': 'mod_presencial',\n    'P3336s2': 'modalidad_trabajo',\n    'P3336s3': 'mod_alternancia',\n    'P3337': 'contacto_maestros',\n    'P6240': 'actividad_principal',\n    'P6250': 'trabajo_pago_1h',\n    'P6260': 'tenia_trabajo_no_trabajo',\n    'P6270': 'trabajo_sin_remuneracion',\n    'P6351': 'disponible_trabajar',\n    'P7250': 'semanas_buscando',\n    'P6920': 'cotiza_pension',\n    'P1082s2': 'tiene_smartphone'\n})\nd
# ...

# %%
df = df.replace(['', ' '], np.nan)
df = df.astype('str')
df = df.replace('nan', np.nan)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 235350 entries, 0 to 235349
# Data columns (total 29 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   DIRECTORIO          235350 non-null  str
#  1   SECUENCIA_ENCUESTA  235350 non-null  str
#  2   SECUENCIA_P         235350 non-null  str
#  3   ORDEN               235350 non-null  str
#  4   P6020               235350 non-null  str
#  5   P6040               235350 non-null  str
#  6   P6051               235350 non-null  str
#  7   FEX_C               235350 non-null  str
#  8   P6090               235350 non-null  str
#  9   P5665               235350 non-null  str
#  10  P8563               7303 non-null    str
#  11  P51                 14307 non-null   str
#  12  P55                 14307 non-null   str
#  13  P774                14227 non-null   str
#  14  P6160               221043 non-null  str
#  15  P8587               166701 non-null  str
# ...

# %%
df = df.drop(columns=['P8587S1', 'P1088S1', 'P6351', 'P3336S1'])

# Rango de códigos VÁLIDOS de respuesta sustantiva, por variable.
# Verifica cada uno contra el diccionario del DANE.
RANGOS = {
    'P6020':   {1, 2},
    'P6051':   set(range(1, 14)),
    'P6090':   {1, 2, 3},
    'P5665':   {1, 2},
    'P8563':   set(range(1, 8)),
    'P51':     set(range(1, 8)),
    'P55':     {1, 2},
    'P774':    set(range(1, 4)),
    'P6160':   {1, 2},
    'P8586':   {1, 2},
    'P8587':   set(range(1, 13)),
    'P1088':   set(range(1, 8)),
    'P6180':   {1, 2},
    'P3336S2': {1, 2},
    'P3336S3': {1, 2},
    'P3337':   {1, 2},
    'P6240':   set(range(1, 6)), 
    'P6250':   {1, 2},
    'P6260':   {1, 2},
    'P6270':   {1, 2},
    'P6920':   {1, 2, 3},
    'P1082S2': {1, 2}
}

# Numéricas: no aplica ninguna regla categórica, solo rango plausible
RANGO_NUM = {
    'P6040':   (0, 120),
    'P7250':   (0, 520)
}

# %%
df['P5665'].value_counts()
# Out:
# P5665
# 2    228047
# 1      7303
# Name: count, dtype: int64

# %%
df.isna().sum() / len(df) * 100
# Out:
# DIRECTORIO             0.000000
# SECUENCIA_ENCUESTA     0.000000
# SECUENCIA_P            0.000000
# ORDEN                  0.000000
# P6020                  0.000000
# P6040                  0.000000
# P6051                  0.000000
# FEX_C                  0.000000
# P6090                  0.000000
# P5665                  0.000000
# P8563                 96.896962
# P51                   93.920969
# P55                   93.920969
# P774                  93.954961
# P6160                  6.079031
# P8587                 29.168897
# P1088                 76.910134
# P6180                 77.675377
# P6250                 58.559592
# P6260                 61.980030
# P6270                 62.630550
# P7250                 97.161674
# P6920                 22.052263
# P8586                  6.079031
# P3336S2               76.910134
# P3336S3               76.910134
# P3337                 80.418101
# P6240                 17.113236
# P1082S2               30.181432
# ...
